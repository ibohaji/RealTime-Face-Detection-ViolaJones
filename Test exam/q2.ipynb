# %%
from skimage import io 
import pydicom as dicom
import numpy as np 
import time
from skimage.util import img_as_float
from skimage.util import img_as_ubyte
import matplotlib.pyplot as plt 
from skimage import color
from skimage.morphology import erosion, dilation, opening, closing

img = io.imread( "nike.png")

# %%
io.imshow(img)

# %% [markdown]
# #### Converts the input image from RGB to HSV

# %%
nike = color.rgb2hsv(img)
io.imshow(nike)

# %% [markdown]
# #### Creates a new image that only contains the H component of the HSV image

# %%
H = nike[:,:,0]

# %% [markdown]
# #### Creates a binary image by setting all pixels with an H value of 0.3 < H < 0.7 to 1 and the rest of the pixels to 0

# %%
import numpy as np 

min_val = 0.3 
max_val = 0.7

binary_mask = np.logical_and(H > min_val, H < max_val).astype(np.uint8)

io.imshow(binary_mask)
# Out:
# c:\Users\User\Documents\imganalysis\DTUImageAnalysis\imganals\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# #### Performs a morphological dilation with a disk shaped structuring element with radius=8 on the binary image.

# %%
mask = dilation(binary_mask,disc(3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Documents\imganalysis\DTUImageAnalysis\Test exam\examq2.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/imganalysis/DTUImageAnalysis/Test%20exam/examq2.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> mask = dilation(binary_mask,disc(3))
#
# NameError: name 'disc' is not defined

# %% [markdown]
# ### What is the number of foreground pixels (value = 1) in the resulting image?
